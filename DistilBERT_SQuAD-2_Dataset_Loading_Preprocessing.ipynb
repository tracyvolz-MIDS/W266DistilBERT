# %% [markdown]
# # Dataset Loading and Preprocessing
#
# SQuAD Dataset 1.0 vs 2.0 -- The Stanford Question Answering Dataset (SQuAD 1.0) is a reading comprehension dataset containing 100,000 question-answer pairs (Rajpurkar, 2016). SQuAD 2.0 contains question-answer pairs from SQuAD 1.0, as well as 50,000 unanswerable questions (Rajpurkar, 2018).  This code will load and pre-process SQuAD 2.0 for the purpose of fine-tuning DistilBERT models.
#
# This notebook contains code to:
# 1. Load the SQuAD 2.0 dataset from Huggingface (https://huggingface.co/datasets/rajpurkar/squad_v2)
# 2. Split the dateset using methods using a traditional split approach -- 80% for Training, 10% for Validation, 10% for Testing (referenced as data_2)
# 3. Preprocessing of each dataset split: Removal of rows of data that failed validation checks
#
# The starting-point for code in this file was found on the blog post titled, Question Answering with DistilBERT (https://medium.com/@sabrinaherbst/question-answering-with-distilbert-ba3e178fdf3d).  Main differences include:
#  - This file handles unanswerable questions needed for SQuAD 2.0
#  - This file contains a traditional split of 80/10/10
#  - Validation at the consolidation phase allowed removal of 315 rows were the expected answer did not match the actual  answer
#
# Rajpurkar, P., Zhang, J., Lopyrev, K., & Liang, P. (2016, October 11). Squad: 100,000+ questions for machine comprehension of text. arXiv.org. https://arxiv.org/abs/1606.05250
#
# Rajpurkar, P., Jia, R., & Liang, P. (2018b, June 11). Know what you don’t know: Unanswerable questions for squad. arXiv.org. https://arxiv.org/abs/1806.03822

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install Huggingface datasets

# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.2)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.17.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 8.7 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 10.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.0 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
# Load libraries

from tqdm.auto import tqdm
from datasets import load_dataset, concatenate_datasets
import os
import pandas as pd
import random
from sklearn.model_selection import train_test_split
from google.colab import drive

# %%
# Load SQuAD 2.0 from Huggingface

dataset = load_dataset("squad_v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/8.92k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/16.4M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
# Look at the structure of the huggingface datasplit

print(dataset)
print(dataset['train']['answers'][500:])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## data_2 File Loading and Initial Data Quality Verification

# %%
# Traditional Split -- 80% for Training, 10% for Validation, 10% for Testing (ie: data_2)
# with pre-processing to remove QA pairs that are defective

def validate_answer(context, answer_text, answer_start):
    """Validate if the answer text matches the context at given start position"""
    # Handle SQuAD 2.0 "impossible" questions
    if answer_text == "" and answer_start == "-1":
        return True

    try:
        start_idx = int(answer_start)
        # Get text from context at the answer position
        extracted_answer = context[start_idx:start_idx+len(answer_text)]

        # Add flexible matching
        if (extracted_answer.lower().strip() == answer_text.lower().strip() or
            extracted_answer.strip() == answer_text.strip()):
            return True

        # If no match, print debug info
        if not (extracted_answer == answer_text):
            print(f"\nValidation failed:")
            print(f"Expected: '{extracted_answer}'")
            print(f"Got: '{answer_text}'")
            print(f"Context: '...{context[max(0, start_idx-20):start_idx+len(answer_text)+20]}...'")
            return False

        return True
    except Exception as e:
        print(f"\nValidation error: {str(e)}")
        return False

def save_samples(data, save_dir, is_pandas=False):
    text = []
    i = 0
    skipped = 0

    save_path = f"/content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/{save_dir}"
    os.makedirs(save_path, exist_ok=True)

    iterator = data.itertuples() if is_pandas else data
    total = len(data)

    for sample in tqdm(iterator, total=total):
        try:
            if is_pandas:
                context = sample.context.replace('\n','')
                question = sample.question.replace('\n','')
                answer_text = sample.answers['text'][0] if len(sample.answers['text']) > 0 else ""
                answer_start = str(sample.answers['answer_start'][0]) if len(sample.answers['answer_start']) > 0 else "-1"
            else:
                context = sample['context'].replace('\n','')
                question = sample['question'].replace('\n','')
                answer_text = sample['answers']['text'][0] if len(sample['answers']['text']) > 0 else ""
                answer_start = str(sample['answers']['answer_start'][0]) if len(sample['answers']['answer_start']) > 0 else "-1"

            # Validate answer position
            if validate_answer(context, answer_text, answer_start):
                text.append([context, question, answer_text, answer_start])
            else:
                skipped += 1
                continue

            if len(text) == 1000:
                filepath = f"{save_path}/text_{i}.txt"
                try:
                    with open(filepath, 'w', encoding='utf-8') as f:
                        f.write("\n".join(["\t".join(t) for t in text]))
                    print(f"Saved chunk {i} to {filepath}")
                except Exception as e:
                    print(f"Error saving chunk {i}: {str(e)}")
                text = []
                i += 1

        except Exception as e:
            print(f"Error processing sample: {str(e)}")
            skipped += 1
            continue

    # Save remaining samples
    if text:
        filepath = f"{save_path}/text_{i}.txt"
        try:
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write("\n".join(["\t".join(t) for t in text]))
            print(f"Saved final chunk {i} to {filepath}")
        except Exception as e:
            print(f"Error saving final chunk: {str(e)}")

    print(f"Skipped {skipped} samples due to invalid answer positions")

try:
    # Combine train and validation sets
    print("\nCombining datasets...")
    full_dataset = concatenate_datasets([dataset["train"], dataset["validation"]])

    # Convert to pandas for easier splitting
    full_df = full_dataset.to_pandas()

    # First split: separate out test set (10%)
    train_val_df, test_df = train_test_split(full_df, test_size=0.1, random_state=42)

    # Second split: separate training (8/9 of remaining) and validation (1/9 of remaining)
    train_df, val_df = train_test_split(train_val_df, test_size=0.111, random_state=42)

    # Print sizes
    print(f"\nDataset sizes:")
    print(f"Train: {len(train_df)} ({len(train_df)/len(full_df)*100:.1f}%)")
    print(f"Validation: {len(val_df)} ({len(val_df)/len(full_df)*100:.1f}%)")
    print(f"Test: {len(test_df)} ({len(test_df)/len(full_df)*100:.1f}%)")

    # Save all three splits
    print("\nSaving training data...")
    save_samples(train_df, "training_squad", is_pandas=True)

    print("\nSaving validation data...")
    save_samples(val_df, "validation_squad", is_pandas=True)

    print("\nSaving test data...")
    save_samples(test_df, "test_squad", is_pandas=True)

    print("\nAll data saved successfully!")

except Exception as e:
    print(f"\nAn error occurred: {str(e)}")
# Out:
# Combining datasets...
#
# Dataset sizes:
# Train: 113767 (80.0%)
# Validation: 14205 (10.0%)
# Test: 14220 (10.0%)
#
# Saving training data...
#   0%|          | 0/113767 [00:00<?, ?it/s]
# Validation failed:
# Expected: 's mantle, of m'
# Got: 'Earth's mantle'
# Context: '...inerals). The Earth's mantle, of much larger mass than...'
#
# Validation failed:
# Expected: 'ute oxygen toxicity ('
# Got: 'Acute oxygen toxicity'
# Context: '...atal for divers). Acute oxygen toxicity (causing seizures, it...'
# Saved chunk 0 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_0.txt
#
# Validation failed:
# Expected: 'roduction of methanol '
# Got: 'production of methanol'
# Context: '...d directly for the production of methanol and related compound...'
#
# Validation failed:
# Expected: 'compression sickness o'
# Got: 'Decompression sickness'
# Context: '... helps kill them. Decompression sickness occurs in divers who ...'
# Saved chunk 1 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_1.txt
#
# Validation failed:
# Expected: 'ye colour or number of limbs,'
# Got: 'eye colour or number of limbs'
# Context: '...y visible, such as eye colour or number of limbs, and some are not, s...'
#
# Validation failed:
# Expected: '969 '
# Got: '1969'
# Context: '...tation, founded in 1969 and operated from a ...'
# Saved chunk 2 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_2.txt
# Saved chunk 3 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_3.txt
#
# Validation failed:
# Expected: 'iffel Tower '
# Got: 'Eiffel Tower'
# Context: '...first level of the Eiffel Tower and finished at the ...'
# Saved chunk 4 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_4.txt
#
# Validation failed:
# Expected: 'he Prince Albert Challenge Cup event.'
# Got: 'The Prince Albert Challenge Cup event'
# Context: '...13 with victory in The Prince Albert Challenge Cup event. The club has been h...'
#
# Validation failed:
# Expected: 'ak Du Ik,'
# Got: 'Pak Du Ik'
# Context: '...o the first runner Pak Du Ik, who played on North...'
# Saved chunk 5 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_5.txt
#
# Validation failed:
# Expected: 'o damage '
# Got: 'no damage'
# Context: '... as Apollo, causes no damage due to the low total...'
#
# Validation failed:
# Expected: '.R. Narisa Chakrabongse,'
# Got: 'M.R. Narisa Chakrabongse'
# Context: '...er city landmarks. M.R. Narisa Chakrabongse, Green World Foundat...'
#
# Validation failed:
# Expected: 'ive '
# Got: 'five'
# Context: '... put out the flame five times (according to ...'
#
# Validation failed:
# Expected: 'zone '
# Got: 'ozone'
# Context: '...s usually known as ozone and is a very reacti...'
# Saved chunk 6 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_6.txt
#
# Validation failed:
# Expected: 'n-cryogenic t'
# Got: 'non-cryogenic'
# Context: '...obtained by these non-cryogenic technologies (see als...'
#
# Validation failed:
# Expected: 'ew Delhi '
# Got: 'New Delhi'
# Context: '... the relay through New Delhi on April 17 was cut ...'
#
# Validation failed:
# Expected: 'achine-to-machine data '
# Got: 'machine-to-machine data'
# Context: '... being used as the machine-to-machine data interoperability sta...'
# Saved chunk 7 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_7.txt
#
# Validation failed:
# Expected: '0 kPa ('
# Got: '160 kPa'
# Context: '...ures greater than 160 kPa (about 1.6 atm) may l...'
# Saved chunk 8 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_8.txt
#
# Validation failed:
# Expected: 'nium(VI) st'
# Got: 'uranium(VI)'
# Context: '...n represents the uranium(VI) state and is known to ...'
#
# Validation failed:
# Expected: 'pril 7,'
# Got: 'April 7'
# Context: '... in Paris, held on April 7, began on the first ...'
#
# Validation failed:
# Expected: 'pected years of schooling ('
# Got: 'Expected years of schooling'
# Context: '...t in schools)EYS: Expected years of schooling (Years that a 5-year-...'
#
# Validation failed:
# Expected: 'acidic solution with other solvents.'
# Got: 'in acidic solution with other solvents'
# Context: '...nd when water is in acidic solution with other solvents....'
#
# Validation failed:
# Expected: 'anberra,'
# Got: 'Canberra'
# Context: '... event was held in Canberra, Australian Capital ...'
#
# Validation failed:
# Expected: 'ultanahmet Square '
# Got: 'Sultanahmet Square'
# Context: '...pril 3, started on Sultanahmet Square and finished in Taks...'
# Saved chunk 9 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_9.txt
#
# Validation failed:
# Expected: 'ss national income at purchasing power parity per capita'
# Got: 'Gross national income at purchasing power parity per capita'
# Context: '... his life)GNIpc: Gross national income at purchasing power parity per capita...'
# Saved chunk 10 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_10.txt
#
# Validation failed:
# Expected: '0 '
# Got: '20'
# Context: '... The relay covered 20 km. No protests or i...'
# Saved chunk 11 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_11.txt
#
# Validation failed:
# Expected: ' by'
# Got: '85%'
# Context: '...re be reduced by 85% by exchanging all inca...'
# Saved chunk 12 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_12.txt
#
# Validation failed:
# Expected: 't has the highest thermal conductivity of any gas.'
# Got: 'it has the highest thermal conductivity of any gas'
# Context: '... stations, because it has the highest thermal conductivity of any gas. Liquid H2 is used i...'
#
# Validation failed:
# Expected: 'erobic or'
# Got: 'anaerobic'
# Context: '...ic to obligately anaerobic organisms, which were ...'
#
# Validation failed:
# Expected: 'r materials in t'
# Got: 'feeder materials'
# Context: '...H) are used as feeder materials in the synthesis of many...'
#
# Validation failed:
# Expected: 'olygenes (many different genes) '
# Got: 'polygenes (many different genes)'
# Context: '...r the influence of polygenes (many different genes) as well as the gene–...'
# Saved chunk 13 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_13.txt
#
# Validation failed:
# Expected: 'xides of silicon '
# Got: 'oxides of silicon'
# Context: '...d in large part of oxides of silicon (silica SiO2, as fou...'
#
# Validation failed:
# Expected: 'igher oxygen content.'
# Got: 'higher oxygen content'
# Context: '... life due to their higher oxygen content. Water polluted with...'
#
# Validation failed:
# Expected: 'nergy content,'
# Got: 'energy content'
# Context: '...lecule. Due to its energy content, O2 is used by compl...'
#
# Validation failed:
# Expected: 'anization is '
# Got: 'Galvanization'
# Context: '...ng or spraying. Galvanization is used on chain-link f...'
#
# Validation failed:
# Expected: 'ak Du Ik,'
# Got: 'Pak Du Ik'
# Context: '...o the first runner Pak Du Ik, who played on North...'
#
# Validation failed:
# Expected: 'agano,'
# Got: 'Nagano'
# Context: '... event was held in Nagano, which hosted the 19...'
# Saved chunk 14 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_14.txt
#
# Validation failed:
# Expected: 'riplet oxygen.'
# Got: 'triplet oxygen'
# Context: '... is referred to as triplet oxygen.[b] The highest ener...'
#
# Validation failed:
# Expected: 'rpentinization by the anaerobic oxidation b'
# Got: 'serpentinization by the anaerobic oxidation'
# Context: '...ng the process of serpentinization by the anaerobic oxidation by the water protons ...'
# Saved chunk 15 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_15.txt
#
# Validation failed:
# Expected: 'ice a'
# Got: 'twice'
# Context: '...endent, and about twice as much (14.6 mg·L−1)...'
#
# Validation failed:
# Expected: 'ndependence Square,'
# Got: 'Independence Square'
# Context: '... from the historic Independence Square, passed in front of ...'
#
# Validation failed:
# Expected: 'stana Square. '
# Got: 'Astana Square.'
# Context: '...m Medeo stadium to Astana Square. There were reports t...'
# Saved chunk 16 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_16.txt
#
# Validation failed:
# Expected: ' no'
# Got: '1⁄3'
# Context: '..., instead of the 1⁄3 normal pressure that w...'
#
# Validation failed:
# Expected: 'reen rust)'
# Got: 'green rust'
# Context: '...ferrous hydroxide (green rust) and can be describe...'
#
# Validation failed:
# Expected: 'stanbul,'
# Got: 'Istanbul'
# Context: '...torch relay leg in Istanbul, held on April 3, st...'
#
# Validation failed:
# Expected: 'pril 3,'
# Got: 'April 3'
# Context: '... Istanbul, held on April 3, started on Sultanah...'
# Saved chunk 17 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_17.txt
#
# Validation failed:
# Expected: 'ighur '
# Got: 'Uighur'
# Context: '... were reports that Uighur activists were arres...'
#
# Validation failed:
# Expected: 'ecial training t'
# Got: 'special training'
# Context: '... systems requires special training to ensure that igniti...'
# Saved chunk 18 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_18.txt
#
# Validation failed:
# Expected: 'des are '
# Got: 'Epoxides'
# Context: '...and acetamide. Epoxides are ethers in which the ...'
#
# Validation failed:
# Expected: 'pril 14.'
# Got: 'April 14'
# Context: '...he Middle East, on April 14. The relay covered 2...'
# Saved chunk 19 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_19.txt
#
# Validation failed:
# Expected: 'aint Petersburg,'
# Got: 'Saint Petersburg'
# Context: '...c torch arrived at Saint Petersburg, Russia. The length ...'
#
# Validation failed:
# Expected: 'werful magnet.['
# Got: 'powerful magnet'
# Context: '...en the poles of a powerful magnet.[c]...'
#
# Validation failed:
# Expected: 'yghurs '
# Got: 'Uyghurs'
# Context: '... in Taksim Square. Uyghurs living in Turkey pro...'
# Saved chunk 20 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_20.txt
#
# Validation failed:
# Expected: 'econciliation Place '
# Got: 'Reconciliation Place'
# Context: '...entral areas, from Reconciliation Place to Commonwealth Park...'
#
# Validation failed:
# Expected: 'y marginally more th'
# Got: 'only marginally more'
# Context: '...rterial blood is only marginally more than normal sea-level ...'
# Saved chunk 21 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_21.txt
#
# Validation failed:
# Expected: 'ranium hexafluoride '
# Got: 'uranium hexafluoride'
# Context: '.... In this process, uranium hexafluoride is repeatedly diffus...'
# Saved chunk 22 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_22.txt
#
# Validation failed:
# Expected: 'aramagnetic.'
# Got: 'paramagnetic'
# Context: '..., O2 molecules are paramagnetic. That is, they impar...'
#
# Validation failed:
# Expected: 'rganic solvents '
# Got: 'organic solvents'
# Context: '...are many important organic solvents that contain oxygen,...'
# Saved chunk 23 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_23.txt
#
# Validation failed:
# Expected: 'pril 28.'
# Got: 'April 28'
# Context: '...ld in Pyongyang on April 28. It was the first ti...'
#
# Validation failed:
# Expected: 'clarative clause: '
# Got: 'declarative clause'
# Context: '... the same as in a declarative clause: "Jij kunt je pen nie...'
#
# Validation failed:
# Expected: 'im Yong Nam.'
# Got: 'Kim Yong Nam'
# Context: '...ntry's parliament, Kim Yong Nam. The North, an ally ...'
# Saved chunk 24 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_24.txt
#
# Validation failed:
# Expected: 'ictory Square '
# Got: 'Victory Square'
# Context: '...h the start at the Victory Square and finish at the Pa...'
#
# Validation failed:
# Expected: ' kPa ('
# Got: '30 kPa'
# Context: '...in general, about 30 kPa (1.4 times normal), a...'
# Saved chunk 25 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_25.txt
#
# Validation failed:
# Expected: 're than 70 s'
# Got: 'more than 70'
# Context: '...ian is offered in more than 70 state-owned schools i...'
#
# Validation failed:
# Expected: 'etronas Twin Towers. '
# Got: 'Petronas Twin Towers.'
# Context: '... end at the iconic Petronas Twin Towers. Among the landmarks ...'
#
# Validation failed:
# Expected: 'enley Royal Regatta '
# Got: 'Henley Royal Regatta'
# Context: '... with many wins at Henley Royal Regatta including most recen...'
#
# Validation failed:
# Expected: 'aris,'
# Got: 'Paris'
# Context: '...torch relay leg in Paris, held on April 7, be...'
#
# Validation failed:
# Expected: 'azakhstan:'
# Got: 'Kazakhstan'
# Context: '... Kazakhstan: The first torchbear...'
# Saved chunk 26 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_26.txt
#
# Validation failed:
# Expected: '920s.'
# Got: '1920s'
# Context: '...veloped in the mid-1920s....'
#
# Validation failed:
# Expected: 'hugs"'
# Got: 'thugs'
# Context: '...mpic Committee as "thugs". A Metropolitan pol...'
#
# Validation failed:
# Expected: 's the rotor coolant '
# Got: 'as the rotor coolant'
# Context: '...elding. H2 is used as the rotor coolant in electrical genera...'
# Saved chunk 27 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_27.txt
# Saved chunk 28 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_28.txt
#
# Validation failed:
# Expected: 'ves ''
# Got: 'joves'
# Context: '...E.g. homes 'men', joves 'youth'....'
#
# Validation failed:
# Expected: 'rodealkylation, hydrodesulfurization, and hydrocracking. H'
# Got: 'hydrodealkylation, hydrodesulfurization, and hydrocracking'
# Context: '...al plant include hydrodealkylation, hydrodesulfurization, and hydrocracking. H2 has several other ...'
# Saved chunk 29 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_29.txt
#
# Validation failed:
# Expected: 'zone '
# Got: 'ozone'
# Context: '... the high-altitude ozone layer helps protect ...'
#
# Validation failed:
# Expected: 'aseous oxygen.'
# Got: 'gaseous oxygen.'
# Context: '...to take up and use gaseous oxygen....'
#
# Validation failed:
# Expected: 'agano,'
# Got: 'Nagano'
# Context: '... event was held in Nagano, which hosted the 19...'
# Saved chunk 30 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_30.txt
# Saved chunk 31 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_31.txt
#
# Validation failed:
# Expected: 'xhibition Road '
# Got: 'Exhibition Road'
# Context: '... in a tunnel under Exhibition Road in 1972. Besides the...'
#
# Validation failed:
# Expected: 'he President of Kazakhstan '
# Got: 'the President of Kazakhstan'
# Context: '...er on April 2, was the President of Kazakhstan Nursultan Nazarbaev....'
# Saved chunk 32 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_32.txt
#
# Validation failed:
# Expected: 'uscat '
# Got: 'Muscat'
# Context: '...Sultanate of Oman: Muscat was the torch's only...'
#
# Validation failed:
# Expected: 'ink paper flowers and small flags '
# Got: 'pink paper flowers and small flags'
# Context: '...f thousands waving pink paper flowers and small flags with the Beijing Oly...'
# Saved chunk 33 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_33.txt
#
# Validation failed:
# Expected: 'n physics and engineering.'
# Got: 'in physics and engineering'
# Context: '... wide applications in physics and engineering. It is used as a shi...'
#
# Validation failed:
# Expected: '2 Arena '
# Got: 'O2 Arena'
# Context: '...ventually ended at O2 Arena in the eastern part ...'
#
# Validation failed:
# Expected: 'ygen gas i'
# Got: 'oxygen gas'
# Context: '... steady stream of oxygen gas is then produced by t...'
# Saved chunk 34 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_34.txt
#
# Validation failed:
# Expected: 'ower '
# Got: 'lower'
# Context: '...olubility of O2 at lower temperatures (see Ph...'
#
# Validation failed:
# Expected: 'hogen attack. O'
# Got: 'pathogen attack'
# Context: '...f plants against pathogen attack. Oxygen is toxic to ob...'
#
# Validation failed:
# Expected: 'wo '
# Got: 'two'
# Context: '...s flew above. Only two Chinese guards were ...'
# Saved chunk 35 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_35.txt
#
# Validation failed:
# Expected: 'bin depressurization. '
# Got: 'cabin depressurization'
# Context: '...o them in case of cabin depressurization. Sudden cabin pressur...'
#
# Validation failed:
# Expected: 'hotosynthesis,'
# Got: 'photosynthesis'
# Context: '... from water during photosynthesis, using the energy of...'
#
# Validation failed:
# Expected: 'igh-altitude ozone layer '
# Got: 'high-altitude ozone layer'
# Context: '...d consequently the high-altitude ozone layer helps protect the bi...'
#
# Validation failed:
# Expected: 'learic),'
# Got: 'Balearic'
# Context: '... (Central), parl (Balearic), parli (Northern), (...'
# Saved chunk 36 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_36.txt
#
# Validation failed:
# Expected: 'he LVMH Group,'
# Got: 'the LVMH Group'
# Context: '...major shareholder, the LVMH Group, of donating funds t...'
#
# Validation failed:
# Expected: 'ive '
# Got: 'five'
# Context: '... relay. A total of five intended torchbearer...'
# Saved chunk 37 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_37.txt
# Saved chunk 38 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_38.txt
# Saved chunk 39 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_39.txt
#
# Validation failed:
# Expected: 'ictory Square '
# Got: 'Victory Square'
# Context: '...h the start at the Victory Square and finish at the Pa...'
#
# Validation failed:
# Expected: '4 times normal),'
# Got: '1.4 times normal'
# Context: '...al, about 30 kPa (1.4 times normal), and the resulting O...'
#
# Validation failed:
# Expected: '978.'
# Got: '1978'
# Context: '...on to democracy in 1978. However, due to ind...'
#
# Validation failed:
# Expected: 'pril 24,'
# Got: 'April 24'
# Context: '...pital Territory on April 24, and covered around ...'
#
# Validation failed:
# Expected: 'or +2 ar'
# Got: '+1 or +2'
# Context: '...tates other than +1 or +2 are known. Calculation...'
# Saved chunk 40 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_40.txt
#
# Validation failed:
# Expected: 'trochemically or as molten zinc by '
# Got: 'electrochemically or as molten zinc'
# Context: '...zinc is applied electrochemically or as molten zinc by hot-dip galvanizing ...'
# Saved chunk 41 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_41.txt
#
# Validation failed:
# Expected: 'llotrope '
# Got: 'allotrope'
# Context: '...is a very reactive allotrope of oxygen that is da...'
#
# Validation failed:
# Expected: 'aichung Bhutia '
# Got: 'Baichung Bhutia'
# Context: '... football captain, Baichung Bhutia refused to take part...'
# Saved chunk 42 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_42.txt
#
# Validation failed:
# Expected: 'y bus '
# Got: 'by bus'
# Context: '...finished the relay by bus instead of being car...'
#
# Validation failed:
# Expected: 'onization of molecular hydrogen from cosmic rays.'
# Got: 'ionization of molecular hydrogen from cosmic rays'
# Context: '...it is generated by ionization of molecular hydrogen from cosmic rays. This charged ion ha...'
#
# Validation failed:
# Expected: 'ydrocarbons '
# Got: 'Hydrocarbons'
# Context: '...related compounds. Hydrocarbons other than methane c...'
#
# Validation failed:
# Expected: 'aksim Square.'
# Got: 'Taksim Square'
# Context: '...re and finished in Taksim Square. Uyghurs living in T...'
#
# Validation failed:
# Expected: 'ustralian and Chinese officials '
# Got: 'Australian and Chinese officials'
# Context: '...e attendants, with Australian and Chinese officials arguing publicly ove...'
# Saved chunk 43 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_43.txt
#
# Validation failed:
# Expected: '96 pounds '
# Got: '196 pounds'
# Context: '...tt bulb will cause 196 pounds (89 kg) of CO2 emiss...'
#
# Validation failed:
# Expected: '964 '
# Got: '1964'
# Context: '...n Malaysia was the 1964 Tokyo edition....'
# Saved chunk 44 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_44.txt
#
# Validation failed:
# Expected: 'chanical ventilators, '
# Got: 'mechanical ventilators'
# Context: '...t for patients on mechanical ventilators, since gas supplied t...'
#
# Validation failed:
# Expected: 'he Eiffel Tower '
# Got: 'the Eiffel Tower'
# Context: '...the first level of the Eiffel Tower and finished at the ...'
#
# Validation failed:
# Expected: '0 '
# Got: '20'
# Context: '...aev. The route ran 20 km from Medeo stadiu...'
# Saved chunk 45 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_45.txt
#
# Validation failed:
# Expected: 'incates '
# Got: 'zincates'
# Context: '... dissolved to form zincates ([Zn(OH)4]2−). The n...'
#
# Validation failed:
# Expected: 'aseous diffusion '
# Got: 'gaseous diffusion'
# Context: '...hment process. The gaseous diffusion process had been the...'
#
# Validation failed:
# Expected: '50,000 '
# Got: '250,000'
# Context: '... the death toll at 250,000 civilians. Around 1,...'
# Saved chunk 46 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_46.txt
# Saved chunk 47 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_47.txt
#
# Validation failed:
# Expected: '0 '
# Got: '70'
# Context: '...was shared amongst 70 runners. It conclude...'
#
# Validation failed:
# Expected: 'ursultan Nazarbaev. '
# Got: 'Nursultan Nazarbaev.'
# Context: '...dent of Kazakhstan Nursultan Nazarbaev. The route ran 20 km ...'
# Saved chunk 48 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_48.txt
#
# Validation failed:
# Expected: 'awater c'
# Got: 'seawater'
# Context: '...er liter, whereas seawater contains about 4.95 m...'
# Saved chunk 49 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_49.txt
#
# Validation failed:
# Expected: ', of m'
# Got: 'mantle'
# Context: '.... The Earth's mantle, of much larger mass than...'
# Saved chunk 50 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_50.txt
#
# Validation failed:
# Expected: 'itrogen '
# Got: 'nitrogen'
# Context: '... which absorbs the nitrogen and delivers a gas s...'
#
# Validation failed:
# Expected: 'nyl carbonate, u'
# Got: 'uranyl carbonate'
# Context: '...ompounds such as uranyl carbonate, uranyl chloride and u...'
#
# Validation failed:
# Expected: 'ecial training t'
# Got: 'special training'
# Context: '... systems requires special training to ensure that igniti...'
# Saved chunk 51 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_51.txt
#
# Validation failed:
# Expected: 'ystal lattice of the fayalite ('
# Got: 'crystal lattice of the fayalite'
# Context: '...te present in the crystal lattice of the fayalite (Fe2SiO4, the olivine...'
#
# Validation failed:
# Expected: 'ormation of ferrous hydroxide '
# Got: 'formation of ferrous hydroxide'
# Context: '...leads first to the formation of ferrous hydroxide (green rust) and can...'
#
# Validation failed:
# Expected: 'arotenoids '
# Got: 'Carotenoids'
# Context: '... of active oxygen. Carotenoids in photosynthetic or...'
# Saved chunk 52 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_52.txt
#
# Validation failed:
# Expected: 'ighur activists '
# Got: 'Uighur activists'
# Context: '... were reports that Uighur activists were arrested and so...'
# Saved chunk 53 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_53.txt
#
# Validation failed:
# Expected: '998 Winter Olympics,'
# Got: '1998 Winter Olympics'
# Context: '..., which hosted the 1998 Winter Olympics, on April 26. Japane...'
# Saved chunk 54 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_54.txt
#
# Validation failed:
# Expected: 'yongyang. '
# Got: 'Pyongyang.'
# Context: '...etre route through Pyongyang. The relay began from...'
#
# Validation failed:
# Expected: '0 '
# Got: '70'
# Context: '...was shared amongst 70 runners. It conclude...'
#
# Validation failed:
# Expected: 'espiration,'
# Got: 'respiration'
# Context: '...sential purpose of respiration, so oxygen supplemen...'
# Saved chunk 55 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_55.txt
#
# Validation failed:
# Expected: 'pril 22.'
# Got: 'April 22'
# Context: '...reached Jakarta on April 22. The original 20 km ...'
#
# Validation failed:
# Expected: 'edor Emelianenko '
# Got: 'Fedor Emelianenko'
# Context: '...avyweight Champion Fedor Emelianenko was one the torch be...'
#
# Validation failed:
# Expected: 'etroleum and chemical industries.'
# Got: 'petroleum and chemical industries'
# Context: '... are needed in the petroleum and chemical industries. The largest applica...'
#
# Validation failed:
# Expected: '2 December 1919.'
# Got: '12 December 1919'
# Context: '...lub was founded on 12 December 1919. The Gold medal winn...'
#
# Validation failed:
# Expected: 'ournalists '
# Got: 'journalists'
# Context: '... Only invitees and journalists were admitted inside...'
#
# Validation failed:
# Expected: 'xygen therapy '
# Got: 'Oxygen therapy'
# Context: '...load on the heart. Oxygen therapy is used to treat emp...'
#
# Validation failed:
# Expected: 'pril 7,'
# Got: 'April 7'
# Context: '... in Paris, held on April 7, began on the first ...'
# Saved chunk 56 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_56.txt
#
# Validation failed:
# Expected: 'uala Lumpur,'
# Got: 'Kuala Lumpur'
# Context: '... the capital city, Kuala Lumpur, on April 21. The 16...'
# Saved chunk 57 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_57.txt
#
# Validation failed:
# Expected: 'emical o'
# Got: 'chemical'
# Context: '...re loss activates chemical oxygen generators abo...'
#
# Validation failed:
# Expected: 'ajor '
# Got: 'major'
# Context: '...the form that is a major part of the Earth's ...'
#
# Validation failed:
# Expected: 'nium dioxide is'
# Got: 'Uranium dioxide'
# Context: '...found in nature. Uranium dioxide is the form in which u...'
#
# Validation failed:
# Expected: 'embley Stadium,'
# Got: 'Wembley Stadium'
# Context: '...n April 6 began at Wembley Stadium, passed through the ...'
#
# Validation failed:
# Expected: 'innah Stadium. '
# Got: 'Jinnah Stadium.'
# Context: '...round the track of Jinnah Stadium. In fear of violent p...'
# Saved chunk 58 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_58.txt
# Saved chunk 59 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_59.txt
#
# Validation failed:
# Expected: 'ower rank courts usually observe Supreme Court interpretations.'
# Got: 'lower rank courts usually observe Supreme Court interpretations'
# Context: '...ecedents; however, lower rank courts usually observe Supreme Court interpretations. In most private law...'
#
# Validation failed:
# Expected: 'eatus,'
# Got: 'beatus'
# Context: '...ssed", (from Latin beatus, blessed, via Greek ...'
#
# Validation failed:
# Expected: 'ultanahmet Square '
# Got: 'Sultanahmet Square'
# Context: '...pril 3, started on Sultanahmet Square and finished in Taks...'
#
# Validation failed:
# Expected: 'lood type, risk for specific diseases, or the thousands of basic biochemical processes that comprise life.'
# Got: 'blood type, risk for specific diseases, or the thousands of basic biochemical processes that comprise life'
# Context: '...e are not, such as blood type, risk for specific diseases, or the thousands of basic biochemical processes that comprise life....'
#
# Validation failed:
# Expected: 'eddy Riner:'
# Got: 'Teddy Riner'
# Context: '...ut to hand over to Teddy Riner: "I understand they'...'
# Saved chunk 60 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_60.txt
#
# Validation failed:
# Expected: 'edor Emelianenko '
# Got: 'Fedor Emelianenko'
# Context: '...avyweight Champion Fedor Emelianenko was one the torch be...'
# Saved chunk 61 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_61.txt
#
# Validation failed:
# Expected: 'our '
# Got: 'four'
# Context: '...swered by God. The four Catholic dogmas rega...'
#
# Validation failed:
# Expected: 'igeria)'
# Got: 'Nigeria'
# Context: '...atunde Osotimehin (Nigeria)2000–2010 Ms Thoraya...'
# Saved chunk 62 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_62.txt
#
# Validation failed:
# Expected: 'ensorship:'
# Got: 'censorship'
# Context: '...situation" through censorship: "All comments poste...'
#
# Validation failed:
# Expected: 'pontaneous '
# Got: 'spontaneous'
# Context: '...ins; this prevents spontaneous combustion....'
#
# Validation failed:
# Expected: 'ochemical oxygen demand, '
# Got: 'biochemical oxygen demand'
# Context: '...uring the water's biochemical oxygen demand, or the amount of O2 ...'
# Saved chunk 63 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_63.txt
#
# Validation failed:
# Expected: 'ive '
# Got: 'five'
# Context: '... relay. A total of five intended torchbearer...'
#
# Validation failed:
# Expected: 'quefied air. '
# Got: 'liquefied air'
# Context: '...l distillation of liquefied air. Liquid oxygen may al...'
#
# Validation failed:
# Expected: 'ow total pressures '
# Got: 'low total pressures'
# Context: '... damage due to the low total pressures used. In the case of...'
# Saved chunk 64 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_64.txt
#
# Validation failed:
# Expected: 'pril 5 '
# Got: 'April 5'
# Context: '... Russia: On April 5 the Olympic torch ar...'
#
# Validation failed:
# Expected: '750,000 '
# Got: '£750,000'
# Context: '...e torch relay cost £750,000 and the participatio...'
#
# Validation failed:
# Expected: 'amu Yokoyama, '
# Got: 'Isamu Yokoyama'
# Context: '... 2 November 1943, Isamu Yokoyama, commander of the Imp...'
#
# Validation failed:
# Expected: 'ondon,'
# Got: 'London'
# Context: '... relay leg held in London, the host city of th...'
#
# Validation failed:
# Expected: 'e Lemkos h'
# Got: 'the Lemkos'
# Context: '...ic affiliation of the Lemkos has become an ideolog...'
# Saved chunk 65 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_65.txt
# Saved chunk 66 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_66.txt
#
# Validation failed:
# Expected: 'aksim Square. '
# Got: 'Taksim Square.'
# Context: '...re and finished in Taksim Square. Uyghurs living in Tu...'
#
# Validation failed:
# Expected: 'C, U2C3'
# Got: '1800 °C'
# Context: '... Stable below 1800 °C, U2C3 is prepared by subj...'
#
# Validation failed:
# Expected: 'eavier '
# Got: 'heavier'
# Context: '...nce uranium 238 is heavier it diffuses slightly...'
# Saved chunk 67 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_67.txt
#
# Validation failed:
# Expected: 'ombustion '
# Got: 'combustion'
# Context: '...ated O2 will allow combustion to proceed rapidly a...'
#
# Validation failed:
# Expected: 'ntifouling paints.'
# Got: 'antifouling paints.'
# Context: '...ithione is used in antifouling paints....'
#
# Validation failed:
# Expected: 'lmaty,'
# Got: 'Almaty'
# Context: '...rst torchbearer in Almaty, where the Olympic t...'
# Saved chunk 68 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_68.txt
#
# Validation failed:
# Expected: 'eart.'
# Got: 'heart'
# Context: '...g work load on the heart. Oxygen therapy is u...'
# Saved chunk 69 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_69.txt
#
# Validation failed:
# Expected: ' message stick,'
# Got: 'a message stick'
# Context: '...turn, offered them a message stick, as a gift of peace ...'
#
# Validation failed:
# Expected: 'agnetite and molecular hydrogen.'
# Got: 'magnetite and molecular hydrogen'
# Context: '...s of water to form magnetite and molecular hydrogen. This process is des...'
#
# Validation failed:
# Expected: 'innah Stadium.'
# Got: 'Jinnah Stadium'
# Context: '...round the track of Jinnah Stadium. In fear of violent ...'
#
# Validation failed:
# Expected: 'hemical '
# Got: 'Chemical'
# Context: '...ides and oxoacids. Chemical catalysts can be use...'
# Saved chunk 70 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_70.txt
#
# Validation failed:
# Expected: 'om Rajawongse Narissara Chakrabongse '
# Got: 'Mom Rajawongse Narissara Chakrabongse'
# Context: '...tended torchbearer Mom Rajawongse Narissara Chakrabongse boycotted the relay,...'
#
# Validation failed:
# Expected: 'akarta '
# Got: 'Jakarta'
# Context: '...mpic flame reached Jakarta on April 22. The ori...'
# Saved chunk 71 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_71.txt
#
# Validation failed:
# Expected: 'eolite molecular sieves,'
# Got: 'zeolite molecular sieves'
# Context: '... pair of identical zeolite molecular sieves, which absorbs the n...'
#
# Validation failed:
# Expected: 'tudent Television of Imperial College)'
# Got: 'Student Television of Imperial College'
# Context: '...V (formerly STOIC (Student Television of Imperial College)) is Imperial Colleg...'
#
# Validation failed:
# Expected: 'othermic r'
# Got: 'exothermic'
# Context: '...n produced by the exothermic reaction....'
#
# Validation failed:
# Expected: 'iatomic oxygen '
# Got: 'Diatomic oxygen'
# Context: '...th the formula O2. Diatomic oxygen gas constitutes 20.8...'
#
# Validation failed:
# Expected: 'ecurity worries"'
# Got: 'security worries'
# Context: '... cancelled due to "security worries", at the request of ...'
#
# Validation failed:
# Expected: ',000 '
# Got: '3,000'
# Context: '...test. An estimated 3,000 French police protec...'
# Saved chunk 72 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_72.txt
#
# Validation failed:
# Expected: 'oreign protesters '
# Got: 'foreign protesters'
# Context: '...reatened to arrest foreign protesters and ban them from fu...'
# Saved chunk 73 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_73.txt
#
# Validation failed:
# Expected: 'CID-compliant transaction processing '
# Got: 'ACID-compliant transaction processing'
# Context: '... industry standard ACID-compliant transaction processing with strong database...'
# Saved chunk 74 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_74.txt
#
# Validation failed:
# Expected: 'tart of the 2014/15 academic year.'
# Got: 'start of the 2014/15 academic year'
# Context: '...ed to ICTV for the start of the 2014/15 academic year....'
#
# Validation failed:
# Expected: '000 '
# Got: '1000'
# Context: '...Stadium. A team of 1000 personnel from the M...'
# Saved chunk 75 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_75.txt
#
# Validation failed:
# Expected: ' wh-question '
# Got: 'a wh-question'
# Context: '...utch equivalent of a wh-question the word order is: i...'
#
# Validation failed:
# Expected: 'he volatilization of zinc in combination with zinc chloride at temperatures above 285 °C '
# Got: 'The volatilization of zinc in combination with zinc chloride at temperatures above 285 °C'
# Context: '...edominant species. The volatilization of zinc in combination with zinc chloride at temperatures above 285 °C indicates the format...'
# Saved chunk 76 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_76.txt
#
# Validation failed:
# Expected: 'arrefour '
# Got: 'Carrefour'
# Context: '...t French hypermart Carrefour from May 1 began spr...'
# Saved chunk 77 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_77.txt
#
# Validation failed:
# Expected: 'rime Minister Yousaf Raza Gillani '
# Got: 'Prime Minister Yousaf Raza Gillani'
# Context: '...rvez Musharraf and Prime Minister Yousaf Raza Gillani spoke at the opening...'
#
# Validation failed:
# Expected: 'tective radiation shield fo'
# Got: 'protective radiation shield'
# Context: '...e functions as a protective radiation shield for the planet. Near t...'
#
# Validation failed:
# Expected: 'ure Land,'
# Got: 'Pure Land'
# Context: '... form of Buddhism, Pure Land, which is characteri...'
# Saved chunk 78 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_78.txt
#
# Validation failed:
# Expected: 'alace Square. '
# Got: 'Palace Square.'
# Context: '... and finish at the Palace Square. Mixed martial arts i...'
#
# Validation failed:
# Expected: 'ulaf Fawakherji.'
# Got: 'Sulaf Fawakherji.'
# Context: '...was Syrian actress Sulaf Fawakherji....'
#
# Validation failed:
# Expected: 'alace Square.'
# Got: 'Palace Square'
# Context: '... and finish at the Palace Square. Mixed martial arts ...'
# Saved chunk 79 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_79.txt
#
# Validation failed:
# Expected: 'd order: "'
# Got: 'word order'
# Context: '...s not change its word order: "Kun jij je pen niet ...'
#
# Validation failed:
# Expected: 'apanese Buddhist temple Zenkō-ji,'
# Got: 'Japanese Buddhist temple Zenkō-ji'
# Context: '...pics, on April 26. Japanese Buddhist temple Zenkō-ji, which was originall...'
# Saved chunk 80 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_80.txt
#
# Validation failed:
# Expected: 'npaired electrons,'
# Got: 'unpaired electrons'
# Context: '...wo. Because of its unpaired electrons, triplet oxygen reac...'
#
# Validation failed:
# Expected: 'lear '
# Got: 'clear'
# Context: '...d and solid O2 are clear substances with a li...'
#
# Validation failed:
# Expected: 'arth's crustal rock '
# Got: 'Earth's crustal rock'
# Context: '...dioxide (CO2). The Earth's crustal rock is composed in large...'
# Saved chunk 81 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_81.txt
#
# Validation failed:
# Expected: 'pril 26.'
# Got: 'April 26'
# Context: '...inter Olympics, on April 26. Japanese Buddhist t...'
#
# Validation failed:
# Expected: 'robic e'
# Got: 'aerobic'
# Context: '...e breathed during aerobic exercise....'
# Saved chunk 82 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_82.txt
#
# Validation failed:
# Expected: 'nterprise database management,'
# Got: 'enterprise database management'
# Context: '...are mostly used in enterprise database management, where XML is being ...'
#
# Validation failed:
# Expected: 'exavalent '
# Got: 'hexavalent'
# Context: '... nitrate and other hexavalent uranium compounds, h...'
# Saved chunk 83 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_83.txt
#
# Validation failed:
# Expected: 're'
# Got: 'UV'
# Context: '... strongly in the UV region of the spectrum...'
#
# Validation failed:
# Expected: 'unming,'
# Got: 'Kunming'
# Context: '...e cities including Kunming, Hefei and Wuhan, ac...'
#
# Validation failed:
# Expected: ' pounds ('
# Got: '30 pounds'
# Context: '...t will only cause 30 pounds (14 kg) of CO2 over t...'
# Saved chunk 84 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_84.txt
#
# Validation failed:
# Expected: 'torage vessels '
# Got: 'storage vessels'
# Context: '...y. Steel pipes and storage vessels used to store and tr...'
#
# Validation failed:
# Expected: 'lmost half '
# Got: 'almost half'
# Context: '...dioxide, making up almost half of the crust's mass....'
#
# Validation failed:
# Expected: 't elevated partial pressures,'
# Got: 'at elevated partial pressures'
# Context: '... (O2) can be toxic at elevated partial pressures, leading to convulsi...'
# Saved chunk 85 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_85.txt
#
# Validation failed:
# Expected: 'aichung Bhutia '
# Got: 'Baichung Bhutia'
# Context: '... football captain, Baichung Bhutia refused to take part...'
#
# Validation failed:
# Expected: 'mitabha '
# Got: 'Amitabha'
# Context: '...c "other-power" of Amitabha Buddha. Pure Land Bu...'
#
# Validation failed:
# Expected: 'pril 28. '
# Got: 'April 28.'
# Context: '...ld in Pyongyang on April 28. It was the first tim...'
#
# Validation failed:
# Expected: 'xygen '
# Got: 'oxygen'
# Context: '...gaseous and liquid oxygen will act as a fuel; ...'
# Saved chunk 86 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_86.txt
# Saved chunk 87 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_87.txt
#
# Validation failed:
# Expected: 'pril 17 '
# Got: 'April 17'
# Context: '...rough New Delhi on April 17 was cut to just 2.3 ...'
# Saved chunk 88 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_88.txt
#
# Validation failed:
# Expected: 'y-product of other reactions;'
# Got: 'by-product of other reactions'
# Context: '...tories, often as a by-product of other reactions; in industry for the...'
# Saved chunk 89 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_89.txt
#
# Validation failed:
# Expected: 'npaired electrons '
# Got: 'unpaired electrons'
# Context: '...tic moments of the unpaired electrons in the molecule, and...'
#
# Validation failed:
# Expected: 'or +2 ar'
# Got: '+1 or +2'
# Context: '...tates other than +1 or +2 are known. Calculation...'
# Saved chunk 90 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_90.txt
#
# Validation failed:
# Expected: 'inding precedents;'
# Got: 'binding precedents'
# Context: '...urts cannot create binding precedents; however, lower rank...'
#
# Validation failed:
# Expected: 'ians as p'
# Got: 'Silesians'
# Context: '...rces that show Silesians as part of the Poles. Pa...'
#
# Validation failed:
# Expected: 'rbon monoxide f'
# Got: 'carbon monoxide'
# Context: '...helps to displace carbon monoxide from the heme group o...'
#
# Validation failed:
# Expected: '0 kilopascals '
# Got: '50 kilopascals'
# Context: '...ressures more than 50 kilopascals (kPa), equal to abou...'
#
# Validation failed:
# Expected: 'ulmonary fibrosis.'
# Got: 'pulmonary fibrosis'
# Context: '... lead to permanent pulmonary fibrosis. Exposure to a O2 pa...'
# Saved chunk 91 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_91.txt
#
# Validation failed:
# Expected: 'upiter.'
# Got: 'Jupiter'
# Context: '...here of the planet Jupiter. The ion is relative...'
#
# Validation failed:
# Expected: 'lacebo '
# Got: 'placebo'
# Context: '...ect is doubtful; a placebo effect is a more lik...'
# Saved chunk 92 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_92.txt
#
# Validation failed:
# Expected: 'uscat '
# Got: 'Muscat'
# Context: '...Sultanate of Oman: Muscat was the torch's only...'
# Saved chunk 93 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_93.txt
#
# Validation failed:
# Expected: 'ulaf Fawakherji.'
# Got: 'Sulaf Fawakherji'
# Context: '...was Syrian actress Sulaf Fawakherji....'
#
# Validation failed:
# Expected: 'rganic molecules '
# Got: 'organic molecules'
# Context: '...ive towards common organic molecules than is molecular ox...'
# Saved chunk 94 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_94.txt
#
# Validation failed:
# Expected: '04 milliliters ('
# Got: '6.04 milliliters'
# Context: '...er contains about 6.04 milliliters (mL) of oxygen per li...'
# Saved chunk 95 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_95.txt
#
# Validation failed:
# Expected: '0 mi)'
# Got: '30 mi'
# Context: '...e city. The 48 km (30 mi) leg took a total of...'
# Saved chunk 96 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_96.txt
#
# Validation failed:
# Expected: 'pril 21.'
# Got: 'April 21'
# Context: '..., Kuala Lumpur, on April 21. The 16.5 km long-re...'
#
# Validation failed:
# Expected: 'pril 18 '
# Got: 'April 18'
# Context: '... Thailand: The April 18 relay through Bangko...'
#
# Validation failed:
# Expected: 'he LVMH Group,'
# Got: 'the LVMH Group'
# Context: '...major shareholder, the LVMH Group, of donating funds t...'
# Saved chunk 97 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_97.txt
#
# Validation failed:
# Expected: 'he Juche Tower,'
# Got: 'the Juche Tower'
# Context: '... of the obelisk of the Juche Tower, which commemorates ...'
# Saved chunk 98 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_98.txt
#
# Validation failed:
# Expected: 'chs bu'
# Got: 'Czechs'
# Context: '...ed themselves as Czechs but significant amount...'
# Saved chunk 99 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_99.txt
#
# Validation failed:
# Expected: '6 '
# Got: '16'
# Context: '...and covered around 16 km of Canberra's cen...'
#
# Validation failed:
# Expected: 'arrefour '
# Got: 'Carrefour'
# Context: '...t French hypermart Carrefour from May 1 began spr...'
#
# Validation failed:
# Expected: 'quid nitrogen a'
# Got: 'liquid nitrogen'
# Context: '...out of air, using liquid nitrogen as a coolant. It is a...'
#
# Validation failed:
# Expected: 'he Chinese embassy,'
# Got: 'the Chinese embassy'
# Context: '... at the request of the Chinese embassy, and the torch was i...'
# Saved chunk 100 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_100.txt
#
# Validation failed:
# Expected: '%–50% O'
# Got: '30%–50%'
# Context: '... composed of only 30%–50% O2 by volume (about 3...'
#
# Validation failed:
# Expected: 'ean years of schooling '
# Got: 'Mean years of schooling'
# Context: '...tancy at birthMYS: Mean years of schooling (Years that a person...'
#
# Validation failed:
# Expected: 'gerous by-products of'
# Got: 'dangerous by-products'
# Context: '...xide (H2O2), are dangerous by-products of oxygen use in organ...'
# Saved chunk 101 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_101.txt
#
# Validation failed:
# Expected: '0% to 93% '
# Got: '90% to 93%'
# Context: '...gas stream that is 90% to 93% O2. Simultaneously, ...'
#
# Validation failed:
# Expected: 'aerobic bacteria t'
# Got: 'anaerobic bacteria'
# Context: '... poisonous to the anaerobic bacteria that cause gas gangre...'
#
# Validation failed:
# Expected: 'uminescent pigments '
# Got: 'luminescent pigments'
# Context: '...e (ZnS) is used in luminescent pigments such as on the hands...'
# Saved chunk 102 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_102.txt
#
# Validation failed:
# Expected: 'quid oxygen i'
# Got: 'Liquid oxygen'
# Context: '...ing O2 molecules. Liquid oxygen is attracted to a mag...'
#
# Validation failed:
# Expected: 'rthern),'
# Got: 'Northern'
# Context: '...Balearic), parli (Northern), ('I speak')....'
# Saved chunk 103 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_103.txt
#
# Validation failed:
# Expected: 'rihydrogen cation.'
# Got: 'trihydrogen cation'
# Context: '...ar hydrogen or the trihydrogen cation....'
# Saved chunk 104 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_104.txt
#
# Validation failed:
# Expected: 'Nafis Sadik (P'
# Got: 'Dr Nafis Sadik'
# Context: '...Arabia)1987–2000 Dr Nafis Sadik (Pakistan)1969–87 Mr R...'
#
# Validation failed:
# Expected: 'mes ''
# Got: 'homes'
# Context: '...xytone words.E.g. homes 'men', joves 'youth'....'
#
# Validation failed:
# Expected: 'low light th'
# Got: 'yellow light'
# Context: '...ion and produces yellow light through fluorescence. ...'
#
# Validation failed:
# Expected: 'mbustible materials.'
# Got: 'combustible materials'
# Context: '...e segregated from combustible materials....'
# Saved chunk 105 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_105.txt
# Saved chunk 106 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_106.txt
#
# Validation failed:
# Expected: 'lessed"'
# Got: 'Blessed'
# Context: '...ccorded the title "Blessed", (from Latin beatus...'
#
# Validation failed:
# Expected: 'anscarpathia and abroad^4'
# Got: 'Transcarpathia and abroad'
# Context: '...emkos residing in Transcarpathia and abroad^4 Most inhabitants of...'
# Saved chunk 107 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_107.txt
#
# Validation failed:
# Expected: 'chikorr reaction:'
# Got: 'Schikorr reaction'
# Context: '...s described by the Schikorr reaction:...'
# Saved chunk 108 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_108.txt
#
# Validation failed:
# Expected: 'ones '
# Got: 'bones'
# Context: '...NA and DNA, and in bones as calcium phosphate...'
# Saved chunk 109 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_109.txt
#
# Validation failed:
# Expected: 'ure Land,'
# Got: 'Pure Land'
# Context: '... form of Buddhism, Pure Land, which is characteri...'
#
# Validation failed:
# Expected: 'tadium. '
# Got: 'stadium.'
# Context: '...nd the city main's stadium. The cancelling of th...'
# Saved chunk 110 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_110.txt
#
# Validation failed:
# Expected: ' municipal building '
# Got: 'a municipal building'
# Context: '...iously the site of a municipal building and now a parking lo...'
#
# Validation failed:
# Expected: 'id-infrared '
# Got: 'mid-infrared'
# Context: '...hat operate in the mid-infrared part of the spectrum...'
#
# Validation failed:
# Expected: 'slamabad '
# Got: 'Islamabad'
# Context: '...mpic torch reached Islamabad for the first time e...'
# Saved chunk 111 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_111.txt
# Saved chunk 112 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_112.txt
#
# Validation failed:
# Expected: 'ranium tricarbide (U'
# Got: 'diuranium tricarbide'
# Context: '...rbide (UC2), and diuranium tricarbide (U2C3). Both UC and UC...'
#
# Validation failed:
# Expected: 'he transmission of genes to an organism's offspring '
# Got: 'The transmission of genes to an organism's offspring'
# Context: '...heredity.:Glossary The transmission of genes to an organism's offspring is the basis of the ...'
#
# Validation failed:
# Expected: 'x silicates (in s'
# Got: 'complex silicates'
# Context: '...cular various complex silicates (in silicate minerals). T...'
#
# Validation failed:
# Expected: 'mperature-d'
# Got: 'temperature'
# Context: '...xygen in water is temperature-dependent, and about ...'
# Saved final chunk 113 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/training_squad/text_113.txt
# Skipped 261 samples due to invalid answer positions
#
# Saving validation data...
#   0%|          | 0/14205 [00:00<?, ?it/s]
# Saved chunk 0 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_0.txt
#
# Validation failed:
# Expected: '964 '
# Got: '1964'
# Context: '...n Malaysia was the 1964 Tokyo edition....'
#
# Validation failed:
# Expected: '0% oxygen '
# Got: '50% oxygen'
# Context: '...a), equal to about 50% oxygen composition at stand...'
# Saved chunk 1 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_1.txt
#
# Validation failed:
# Expected: 'ustralian Federal Police. '
# Got: 'Australian Federal Police.'
# Context: '... kept apart by the Australian Federal Police. Preparations for the...'
#
# Validation failed:
# Expected: 'ellular respiration '
# Got: 'cellular respiration'
# Context: '...uch as animals, in cellular respiration (see Biological role...'
# Saved chunk 2 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_2.txt
# Saved chunk 3 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_3.txt
#
# Validation failed:
# Expected: 'rotonated '
# Got: 'protonated'
# Context: '... H+3 ion, known as protonated molecular hydrogen o...'
#
# Validation failed:
# Expected: 'rrested '
# Got: 'arrested'
# Context: '...elay were promptly arrested by the police....'
# Saved chunk 4 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_4.txt
#
# Validation failed:
# Expected: 'oraya Ahmed Obaid ('
# Got: 'Thoraya Ahmed Obaid'
# Context: '...eria)2000–2010 Ms Thoraya Ahmed Obaid (Saudi Arabia)1987–20...'
#
# Validation failed:
# Expected: 'arments,'
# Got: 'garments'
# Context: '...isted electronics, garments, toys and coal among...'
# Saved chunk 5 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_5.txt
#
# Validation failed:
# Expected: 'yl acetate.'
# Got: 'uranyl acetate'
# Context: '...red of which is uranyl acetate....'
#
# Validation failed:
# Expected: 'erpetual virginity of Mary,'
# Got: 'Perpetual virginity of Mary'
# Context: '...re: Mother of God, Perpetual virginity of Mary, Immaculate Concepti...'
#
# Validation failed:
# Expected: 'ndependence Square,'
# Got: 'Independence Square'
# Context: '... from the historic Independence Square, passed in front of ...'
#
# Validation failed:
# Expected: ' locus (or region) of DNA that encodes a functional RNA or protein product,'
# Got: 'a locus (or region) of DNA that encodes a functional RNA or protein product'
# Context: '...A gene is a locus (or region) of DNA that encodes a functional RNA or protein product, and is the molecula...'
# Saved chunk 6 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_6.txt
#
# Validation failed:
# Expected: 'orthwestern)'
# Got: 'Northwestern'
# Context: '...arlo, temo, sento (Northwestern). In verbs, 1st pers...'
# Saved chunk 7 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_7.txt
#
# Validation failed:
# Expected: '0 '
# Got: '20'
# Context: '...l 22. The original 20 km relay through Jak...'
#
# Validation failed:
# Expected: 'ondon,'
# Got: 'London'
# Context: '... relay leg held in London, the host city of th...'
#
# Validation failed:
# Expected: 'xygen supplementation '
# Got: 'oxygen supplementation'
# Context: '...of respiration, so oxygen supplementation is used in medicine....'
# Saved chunk 8 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_8.txt
#
# Validation failed:
# Expected: 'pril 6 '
# Got: 'April 6'
# Context: '...ummer Olympics, on April 6 began at Wembley Sta...'
#
# Validation failed:
# Expected: 'gnes Shea,'
# Got: 'Agnes Shea'
# Context: '...l Aboriginal elder Agnes Shea, of the Ngunnawal pe...'
# Saved chunk 9 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_9.txt
#
# Validation failed:
# Expected: '0 '
# Got: '10'
# Context: '... covered just over 10 km, and included Ban...'
# Saved chunk 10 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_10.txt
# Saved chunk 11 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_11.txt
#
# Validation failed:
# Expected: 'uranium octoxide is'
# Got: 'Triuranium octoxide'
# Context: '...ntal conditions. Triuranium octoxide is (depending on condi...'
#
# Validation failed:
# Expected: 'pril 16.'
# Got: 'April 16'
# Context: '...first time ever on April 16. President Pervez Mu...'
# Saved chunk 12 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_12.txt
#
# Validation failed:
# Expected: 'erformance.'
# Got: 'performance'
# Context: '...o get a "boost" in performance. The pharmacological...'
#
# Validation failed:
# Expected: '2 '
# Got: 'O2'
# Context: '... (see Occurrence). O2 has a bond length of...'
#
# Validation failed:
# Expected: 'xides and oxoacids.'
# Got: 'oxides and oxoacids'
# Context: '... O2 evolution from oxides and oxoacids. Chemical catalysts ...'
# Saved chunk 13 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_13.txt
# Saved final chunk 14 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/validation_squad/text_14.txt
# Skipped 24 samples due to invalid answer positions
#
# Saving test data...
#   0%|          | 0/14220 [00:00<?, ?it/s]
# Validation failed:
# Expected: '014,'
# Got: '2014'
# Context: '...ing enterprises.In 2014, the U.S. Department...'
#
# Validation failed:
# Expected: 'utside the stadium.'
# Got: 'outside the stadium.'
# Context: '...rotests took place outside the stadium....'
# Saved chunk 0 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_0.txt
#
# Validation failed:
# Expected: 'cited form a'
# Got: 'excited form'
# Context: '... only exist in an excited form and is unstable. By c...'
#
# Validation failed:
# Expected: 'yghurs living in Turkey '
# Got: 'Uyghurs living in Turkey'
# Context: '... in Taksim Square. Uyghurs living in Turkey protested at Chinese...'
#
# Validation failed:
# Expected: ' '
# Got: '3'
# Context: '...house and included 3 alumni of the colleg...'
#
# Validation failed:
# Expected: 'artin McElroy.'
# Got: 'Martin McElroy'
# Context: '...g with their coach Martin McElroy. The club has been h...'
# Saved chunk 1 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_1.txt
#
# Validation failed:
# Expected: ', of m'
# Got: 'mantle'
# Context: '.... The Earth's mantle, of much larger mass than...'
# Saved chunk 2 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_2.txt
#
# Validation failed:
# Expected: 'alencian)'
# Got: 'Valencian'
# Context: '... parle, tem, sent (Valencian); parlo, temo, sento...'
#
# Validation failed:
# Expected: 'troy invading microbes. R'
# Got: 'destroy invading microbes'
# Context: '...inglet oxygen to destroy invading microbes. Reactive oxygen speci...'
#
# Validation failed:
# Expected: 'ursultan Nazarbaev. '
# Got: 'Nursultan Nazarbaev.'
# Context: '...dent of Kazakhstan Nursultan Nazarbaev. The route ran 20 km ...'
# Saved chunk 3 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_3.txt
#
# Validation failed:
# Expected: 'gnes Shea,'
# Got: 'Agnes Shea'
# Context: '...l Aboriginal elder Agnes Shea, of the Ngunnawal pe...'
#
# Validation failed:
# Expected: 'traviolet radiation i'
# Got: 'ultraviolet radiation'
# Context: '...roduced solely by ultraviolet radiation impacting oxygen-cont...'
# Saved chunk 4 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_4.txt
#
# Validation failed:
# Expected: 'izures, '
# Got: 'seizures'
# Context: '...toxicity (causing seizures, its most feared effe...'
#
# Validation failed:
# Expected: 'he French flag,'
# Got: 'the French flag'
# Context: '...zism's Swastika to the French flag, and spread short on...'
#
# Validation failed:
# Expected: 'ollo 1 crew i'
# Got: 'Apollo 1 crew'
# Context: '...e that killed the Apollo 1 crew in a launch pad test ...'
# Saved chunk 5 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_5.txt
#
# Validation failed:
# Expected: 'ntibonding,'
# Got: 'antibonding'
# Context: '...illed orbitals are antibonding, and so their fillin...'
# Saved chunk 6 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_6.txt
# Saved chunk 7 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_7.txt
#
# Validation failed:
# Expected: 'billion years ago dur'
# Got: '2.5 billion years ago'
# Context: '...tmosphere about 2.5 billion years ago during the Great Oxygen...'
#
# Validation failed:
# Expected: 'xpelling reducing equivalents in biochemical reactions.'
# Got: 'expelling reducing equivalents in biochemical reactions'
# Context: '...ture as a means of expelling reducing equivalents in biochemical reactions....'
# Saved chunk 8 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_8.txt
#
# Validation failed:
# Expected: 'oom '
# Got: 'room'
# Context: '...aneously in air at room temperature....'
#
# Validation failed:
# Expected: 'agnetic field,'
# Got: 'magnetic field'
# Context: '... the presence of a magnetic field, because of the spin...'
# Saved chunk 9 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_9.txt
#
# Validation failed:
# Expected: 'se of carbon monoxide through the water gas shift reaction,'
# Got: 'use of carbon monoxide through the water gas shift reaction'
# Context: '... from the steam by use of carbon monoxide through the water gas shift reaction, especially with an ...'
#
# Validation failed:
# Expected: 'ryogenic '
# Got: 'cryogenic'
# Context: '...quid H2 is used in cryogenic research, including ...'
#
# Validation failed:
# Expected: '.5 '
# Got: '1.5'
# Context: '... 2.3 km (less than 1.5 miles), which was sh...'
# Saved chunk 10 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_10.txt
#
# Validation failed:
# Expected: 'pril 18 '
# Got: 'April 18'
# Context: '... Thailand: The April 18 relay through Bangko...'
#
# Validation failed:
# Expected: 'tudents '
# Got: 'students'
# Context: '...Tibet. In Bangkok, students told the media that ...'
# Saved chunk 11 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_11.txt
#
# Validation failed:
# Expected: 'tructured document-oriented database '
# Got: 'structured document-oriented database'
# Context: '...ases are a type of structured document-oriented database that allows querying...'
#
# Validation failed:
# Expected: 'ung tissue.'
# Got: 'lung tissue'
# Context: '...hat is damaging to lung tissue. Ozone is produced i...'
#
# Validation failed:
# Expected: 'el M. Salas (Ph'
# Got: 'Rafael M. Salas'
# Context: '...stan)1969–87 Mr Rafael M. Salas (Philippines)...'
# Saved chunk 12 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_12.txt
#
# Validation failed:
# Expected: 'hotolysis of ozone '
# Got: 'photolysis of ozone'
# Context: '...troposphere by the photolysis of ozone by light of short wa...'
#
# Validation failed:
# Expected: 'lgae '
# Got: 'algae'
# Context: '...timulate growth of algae by a process called ...'
# Saved chunk 13 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_13.txt
# Saved final chunk 14 to /content/drive/MyDrive/distilBERT_SQuAD2_w266Project/data_2/test_squad/text_14.txt
# Skipped 30 samples due to invalid answer positions
#
# All data saved successfully!

# %% [markdown]
# # data_2 File Inspection

# %%
# Open a data_2 text file

with open("/content/drive/MyDrive/24Nov2024_distilbert_squad_2/data_2/training_squad/text_0.txt", 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

lines_2 = pd.DataFrame([line.split("\t") for line in lines], columns=["context", "question", "answer", "answer_start"])

# %%
# Verify the DataFrame has exactly 1000 rows and 4 columns

assert lines_2.shape==(1000,4)
print("Passed")
# Out:
# Passed

# %%
# Verify that the answer_start position correctly locates each answer within its context

for ind, line in lines_2.iterrows():
    sample = line
    answer_start = int(sample['answer_start'])
    assert sample['context'][answer_start:answer_start+len(sample['answer'])] == sample['answer']
print("Passed")
# Out:
# Passed

# %% [markdown]
# ## Summary of Dataset Split and Pre-Processing
# Data quality verification tasks identified 315 question-answer pairs where the expected answer did not match the true answer (See Appendix A:  Initial Data Quality Verification).  These question-answer pairs were removed as they make up an insignificant portion (~0.2%) of the dataset (See Appendix A—Initial Data Quality Verification).
